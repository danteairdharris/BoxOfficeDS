# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import pickle
from datetime import datetime
import os

# %%
## Save list_movie_data in with pickle
def save_data(filename, data):
    with open(filename, 'wb') as f:
        pickle.dump(data, f)

## Load pickle file data 
def load_data(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)
    
#function for scraping infobox
def scrape(url):
    page = requests.get(url)
    toScrape = bs(page.content, 'html.parser')
    movie_details = toScrape.find(class_='infobox vevent')
    rows = movie_details.find_all('tr') 
    movie_data = {}

    title = rows[0].find('th').get_text()
    movie_data['Title'] = title
    for i, row in enumerate(rows):
        try:
            if i <= 1:
                continue
            elif row.find('th').get_text() == 'Based on':
                continue
            elif row.find('th').get_text() == 'Starring':
                clean_tags(row)
                movie_data['Starring'] = clean(row)
                movie_data['Lead'] = movie_data['Starring'][0]
            elif 'Production' in row.find('th').get_text():
                clean_tags(row)
                movie_data['Production companies'] = clean(row)
            elif row.find('th').get_text() == 'Running time':
                clean_tags(row)
                movie_data['Running_time_min'] = clean(row)
            elif row.find('th').get_text() == 'Release date':
                clean_tags(row)
                date = clean(row).strip()
                dt = dt_conversion(date)
                movie_data['Release_date_dt'] = dt
                movie_data['Release_month'] = dt.month
            elif row.find('th').get_text() == 'Budget':
                budget = money_convert(row)
                movie_data['Budget'] = budget
            elif row.find('th').get_text() == 'Box office':
                money = money_convert(row)
                movie_data['Box_office'] = money
            else:
                clean_tags(row)
                column = row.find('th').get_text(' ', strip=True)
                data = clean(row)
                movie_data[column] = data
        except:
            pass
        
    op_rating = get_op_and_rating(title)
    movie_data['Box_office_opening'] = op_rating[0]
    movie_data['Rating'] = op_rating[1]
        
    return movie_data
    
    
    
#grab opening box office numbers and MPAA rating from Box Office Mojo given movie title
def get_op_and_rating(title):
    search_page = requests.get('https://www.boxofficemojo.com/search/?q='+title)
    search_page_content = bs(search_page.content, 'html.parser')
    search_list = search_page_content.find_all('a')
    path = ''
    for li in search_list:
        if li.get_text() == title:
            path = li['href']
            break
        elif title[:10] in li.get_text():
            path = li['href']
            break
            
    if path == '':
        path = search_list[14]['href']
    
    
    data = [None,'Unknown']
    movie_page = requests.get('https://www.boxofficemojo.com'+path)
    movie_page_content = bs(movie_page.content, 'html.parser')
    table_links = movie_page_content.find_all('a')
    for li in table_links:
        if '$' in li.get_text():
            opening_box = float(li.get_text().replace('$', '').replace(',', ''))
            data[0] = opening_box
            break
            
    spans = movie_page_content.find_all('span')
    for span in spans:
        if 'MPAA' in span.get_text():
            rating = span.find_next('span').get_text()
            data[1] = rating
            break
    return data  


#Convert date str to datetime object
def dt_conversion(date):
    patterns = ['%B %d, %Y', '%d %B %Y']
    for pat in patterns:
        try:
            return datetime.strptime(date, pat)
        except:
            pass
    return none


#remove troublesome tags
def clean_tags(content):
    t = ['sup', 'span']
    tags = content.find_all(t)
    for tag in tags:
        tag.decompose()

def money_convert(row):
    multiplier = 1
    money_str = row.find('td').get_text().replace('\xa0', ' ')
    if '£' in money_str:
        multiplier = 1.41
    elif '€' in money_str:
        multiplier = 1.21
        
        
    if 'million' in money_str:
        if '(' in money_str:
            money_str = money_str.split('(')[0].replace('$','').replace('£', '')
        if '-' in money_str:
            number = float(money_str.split('-')[0].replace('$','').replace('£', ''))
            return number * multiplier * (10**6)
        if '–' in money_str:
            number = float(money_str.split('–')[0].replace('$','').replace('£', ''))
            return number * multiplier * (10**6)
        else:
            number = float(money_str.split(' ')[0].replace('$','').replace('£', ''))
            return number * multiplier * (10**6)
    elif 'billion' in money_str:
        if '(' in money_str:
            money_str = money_str.split('(')[0].replace('$','').replace('£', '')
        if '-' in money_str:
            number = float(money_str.split('-')[0].replace('$','').replace('£', ''))
            return number * multiplier * (10**9)
        if '–' in money_str:
            number = float(money_str.split('–')[0].replace('$','').replace('£', ''))
            return number * multiplier * (10**9)
        else:
            number = float(money_str.split(' ')[0].replace('$','').replace('£', ''))
            return number * multiplier * (10**9)
    else:
        number = float(money_str.replace(',','').replace('$','').replace('£', ''))
        return number * multiplier


#function to clean data scraped from wikipedia infobox
def clean(row):
    if row.find('th').get_text() == 'Release date':
        if row.find('td').get_text()[0].isdigit() == True:
            return row.find('td').get_text().split(',')[0].replace('\xa0', ' ').strip('\n').strip(' ')  
        return row.find('td').get_text().split('(')[0].replace('\xa0', ' ').strip('\n').strip(' ')                                                                                         
    elif row.find('th').get_text() == 'Running time':
        return int(row.find('td').get_text().split(' ')[0])
    elif row.find('br'):
        return [text for text in row.find('td').stripped_strings]
    elif row.find('li'):
        return [li.get_text(' ', strip=True).replace('\xa0', ' ') for li in row.find_all('li')]
    return row.find('td').get_text()

# %% [markdown]
# # Scrape single page and add to movie data

# %%
# load movie data 
list_movie_data = load_data('./1990-2019_movie_data.pickle')

#list_movie_data.append(scrape(#some wikipedia link to movie infobox))

#save_data('moviestudio_movie_data.pickle', list_movie_data)
save_data('1990-2019_movie_data.pickle', list_movie_data)

# Delete irrelevant columns
df = pd.DataFrame(list_movie_data) 
while True:
    try:
        df.drop(df.columns[21], axis=1, inplace = True)
    except:
        break
df.drop(df.columns[[3,4,7,9]], axis=1, inplace = True)
df = df.set_index('Title')

# drop rows without box office numbers and create seperate csv and dataframe
df1 = df.dropna(subset=['Release_month','Budget', 'Box_office_opening', 'Box_office'])

#change file name accordingly
#df.to_csv('moviestudio_movie_data_cleaned.csv')
df.to_csv('../Data/all_movie_data_cleaned.csv')
# df1.to_csv(#moviestudio_movie_data_dropna.csv')     
df1.to_csv('../Data/all_movie_data_dropna.csv')
# Out:
#                                                                            Directed by  \
# Title
# Iron Man                                                                   Jon Favreau
# The Incredible Hulk                                                    Louis Leterrier
# Iron Man 2                                                                 Jon Favreau
# Thor                                                                   Kenneth Branagh
# Captain America: The First Avenger                                        Joe Johnston
# The Avengers                                                               Joss Whedon
# Iron Man 3                                                                 Shane Black
# Thor: The Dark World                                                       Alan Taylor
# Captain America: The Winter Soldier                         [Anthony Russo, Joe Russo]
# Guardians of the Galaxy                                                     James Gunn
# Avengers: Age of Ultron                                                    Joss Whedon
# Ant-Man                                                                    Peyton Reed
# Captain America: Civil War           [Anthony Russo Joe Russo, Anthony Russo, Joe R...
# Doctor Strange                                                        Scott Derrickson
# Guardians of the Galaxy Vol. 2                                              James Gunn
# Spider-Man: Homecoming                                                       Jon Watts
# Thor: Ragnarok                                                           Taika Waititi
# Black Panther                                                             Ryan Coogler
# Avengers: Infinity War                                      [Anthony Russo, Joe Russo]
# Ant-Man and the Wasp                                                       Peyton Reed
# Captain Marvel                                                [Anna Boden, Ryan Fleck]
# Avengers: Endgame                                           [Anthony Russo, Joe Russo]
# Spider-Man: Far From Home                                                    Jon Watts
#
#                                                                               Starring  \
# Title
# Iron Man                             [Robert Downey Jr., Terrence Howard, Jeff Brid...
# The Incredible Hulk                  [Edward Norton, Liv Tyler, Tim Roth, Tim Blake...
# Iron Man 2                           [Robert Downey Jr., Gwyneth Paltrow, Don Chead...
# Thor                                 [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# Captain America: The First Avenger   [Chris Evans, Tommy Lee Jones, Hugo Weaving, H...
# The Avengers                         [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# Iron Man 3                           [Robert Downey Jr., Gwyneth Paltrow, Don Chead...
# Thor: The Dark World                 [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# Captain America: The Winter Soldier  [Chris Evans, Scarlett Johansson, Sebastian St...
# Guardians of the Galaxy              [Chris Pratt, Zoe Saldana, Dave Bautista, Vin ...
# Avengers: Age of Ultron              [Robert Downey Jr., Chris Hemsworth, Mark Ruff...
# Ant-Man                              [Paul Rudd, Evangeline Lilly, Corey Stoll, Bob...
# Captain America: Civil War           [Chris Evans, Robert Downey Jr., Scarlett Joha...
# Doctor Strange                       [Benedict Cumberbatch, Chiwetel Ejiofor, Rache...
# Guardians of the Galaxy Vol. 2       [Chris Pratt, Zoe Saldana, Dave Bautista, Vin ...
# Spider-Man: Homecoming               [Tom Holland, Michael Keaton, Jon Favreau, Gwy...
# Thor: Ragnarok                       [Chris Hemsworth, Tom Hiddleston, Cate Blanche...
# Black Panther                        [Chadwick Boseman, Michael B. Jordan, Lupita N...
# Avengers: Infinity War               [Robert Downey Jr., Chris Hemsworth, Mark Ruff...
# Ant-Man and the Wasp                 [Paul Rudd, Evangeline Lilly, Michael Peña, Wa...
# Captain Marvel                       [Brie Larson, Samuel L. Jackson, Ben Mendelsoh...
# Avengers: Endgame                    [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# Spider-Man: Far From Home            [Tom Holland, Samuel L. Jackson, Zendaya, Cobi...
#
#                                                      Lead Release_date_dt  \
# Title
# Iron Man                                Robert Downey Jr.      2008-04-14
# The Incredible Hulk                         Edward Norton      2008-06-08
# Iron Man 2                              Robert Downey Jr.      2010-04-26
# Thor                                      Chris Hemsworth      2011-04-17
# Captain America: The First Avenger            Chris Evans      2011-07-19
# The Avengers                            Robert Downey Jr.      2012-04-11
# Iron Man 3                              Robert Downey Jr.      2013-04-14
# Thor: The Dark World                      Chris Hemsworth      2013-10-22
# Captain America: The Winter Soldier           Chris Evans      2014-03-13
# Guardians of the Galaxy                       Chris Pratt      2014-07-21
# Avengers: Age of Ultron                 Robert Downey Jr.      2015-04-13
# Ant-Man                                         Paul Rudd      2015-06-29
# Captain America: Civil War                    Chris Evans      2016-04-12
# Doctor Strange                       Benedict Cumberbatch      2016-10-13
# Guardians of the Galaxy Vol. 2                Chris Pratt      2017-04-10
# Spider-Man: Homecoming                        Tom Holland      2017-06-28
# Thor: Ragnarok                            Chris Hemsworth      2017-10-10
# Black Panther                            Chadwick Boseman      2018-01-29
# Avengers: Infinity War                  Robert Downey Jr.      2018-04-23
# Ant-Man and the Wasp                            Paul Rudd      2018-06-25
# Captain Marvel                                Brie Larson      2019-02-27
# Avengers: Endgame                       Robert Downey Jr.      2019-04-22
# Spider-Man: Far From Home                     Tom Holland      2019-06-26
#
#                                      Release_month  Running_time_min  \
# Title
# Iron Man                                         4               126
# The Incredible Hulk                              6               112
# Iron Man 2                                       4               125
# Thor                                             4               114
# Captain America: The First Avenger               7               124
# The Avengers                                     4               143
# Iron Man 3                                       4               131
# Thor: The Dark World                            10               112
# Captain America: The Winter Soldier              3               136
# Guardians of the Galaxy                          7               122
# Avengers: Age of Ultron                          4               141
# Ant-Man                                          6               117
# Captain America: Civil War                       4               147
# Doctor Strange                                  10               115
# Guardians of the Galaxy Vol. 2                   4               137
# Spider-Man: Homecoming                           6               133
# Thor: Ragnarok                                  10               130
# Black Panther                                    1               134
# Avengers: Infinity War                           4               149
# Ant-Man and the Wasp                             6               118
# Captain Marvel                                   2               124
# Avengers: Endgame                                4               181
# Spider-Man: Far From Home                        6               129
#
#                                            Country Language       Budget  \
# Title
# Iron Man                             United States  English  140000000.0
# The Incredible Hulk                  United States  English  137500000.0
# Iron Man 2                           United States  English  170000000.0
# Thor                                 United States  English  150000000.0
# Captain America: The First Avenger   United States  English  140000000.0
# The Avengers                         United States  English  220000000.0
# Iron Man 3                           United States  English  200000000.0
# Thor: The Dark World                 United States  English  150000000.0
# Captain America: The Winter Soldier  United States  English  170000000.0
# Guardians of the Galaxy              United States  English  232300000.0
# Avengers: Age of Ultron              United States  English  444000000.0
# Ant-Man                              United States  English  130000000.0
# Captain America: Civil War           United States  English  250000000.0
# Doctor Strange                       United States  English  165000000.0
# Guardians of the Galaxy Vol. 2       United States  English  200000000.0
# Spider-Man: Homecoming               United States  English  175000000.0
# Thor: Ragnarok                       United States  English  180000000.0
# Black Panther                        United States  English  200000000.0
# Avengers: Infinity War               United States  English  325000000.0
# Ant-Man and the Wasp                 United States  English  130000000.0
# Captain Marvel                       United States  English  152000000.0
# Avengers: Endgame                    United States  English  356000000.0
# Spider-Man: Far From Home            United States  English  160000000.0
#
#                                        Box_office  Box_office_opening Rating
# Title
# Iron Man                             5.858000e+08          98618668.0  PG-13
# The Incredible Hulk                  2.648000e+08          55414050.0  PG-13
# Iron Man 2                           6.239000e+08         128122480.0  PG-13
# Thor                                 4.493000e+08          65723338.0  PG-13
# Captain America: The First Avenger   3.706000e+08          65058524.0  PG-13
# The Avengers                         1.519000e+09         207438708.0  PG-13
# Iron Man 3                           1.215000e+09         174144585.0  PG-13
# Thor: The Dark World                 6.448000e+08          85737841.0  PG-13
# Captain America: The Winter Soldier  7.144000e+08          95023721.0  PG-13
# Guardians of the Galaxy              7.728000e+08          94320883.0  PG-13
# Avengers: Age of Ultron              1.403000e+09         191271109.0  PG-13
# Ant-Man                              5.193000e+08          57225526.0  PG-13
# Captain America: Civil War           1.153000e+09         179139142.0  PG-13
# Doctor Strange                       6.777000e+08          85058311.0  PG-13
# Guardians of the Galaxy Vol. 2       8.638000e+08         146510104.0  PG-13
# Spider-Man: Homecoming               8.802000e+08         117027503.0  PG-13
# Thor: Ragnarok                       8.540000e+08         122744989.0  PG-13
# Black Panther                        1.348000e+09         202003951.0  PG-13
# Avengers: Infinity War               2.048000e+09         257698183.0  PG-13
# Ant-Man and the Wasp                 6.227000e+08          75812205.0  PG-13
# Captain Marvel                       1.128000e+09         153433423.0  PG-13
# Avengers: Endgame                    2.798000e+09         357115007.0  PG-13
# Spider-Man: Far From Home            1.132000e+09          92579212.0  PG-13
